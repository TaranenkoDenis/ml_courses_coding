# %% [markdown]
# ## Random Forest Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset['Salary']

# %% [markdown]
# ### Training the Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import plot_tree

# n_estimators is a number of trees
regressor = RandomForestRegressor(n_estimators=10, random_state=0)
regressor.fit(X, y)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %% [markdown]
# ### Predict a new result

# %%
regressor.predict([[6.5]])
# Out:
# array([167000.])

# %% [markdown]
# ### Visualizing the Random Forest Regressor results (in high resolution)

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape(len(X_grid), 1)

plt.scatter(X, y, color='red', label='Actual Salaries')
plt.plot(X_grid, regressor.predict(X_grid), color='blue', label='Predicted Salaries')
plt.legend()
plt.title('Salary vs Position (Truth or Bluff)')
plt.show()
# Out:
# /var/folders/cf/jwy0c4s50112j4n35pczmxgc0000gn/T/ipykernel_62131/2296212073.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.1)
